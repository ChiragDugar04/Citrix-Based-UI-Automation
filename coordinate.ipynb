# %%
import pyautogui
import time
time.sleep(5)
print("--- Coordinate Helper ---")
print("Move your mouse to the Top-Left corner of the table and wait...")
print(f"TOP-LEFT: {pyautogui.position()}")
# Out:
# --- Coordinate Helper ---
# Move your mouse to the Top-Left corner of the table and wait...
# TOP-LEFT: Point(x=418, y=222)

# %%
print("\nMove your mouse to the Bottom-Right corner of the table and wait...")
time.sleep(3)
print(f"BOTTOM-RIGHT: {pyautogui.position()}")
# Out:
# Move your mouse to the Bottom-Right corner of the table and wait...
# BOTTOM-RIGHT: Point(x=1502, y=716)

# %%
print("\nMove your mouse to the 'Scroll Down' button and wait...")
time.sleep(3)
print(f"SCROLL BUTTON: {pyautogui.position()}")
# Out:
# Move your mouse to the 'Scroll Down' button and wait...
# SCROLL BUTTON: Point(x=1909, y=994)

# %%
import pandas as pd
data=pd.read_csv("intelligent_scraped_data.csv")

# %%
data
# Out:
#             Country     Population Percentage
# 0             India  1,417,492,000      17.2%
# 1             China  1,404,890,000      17.1%
# 2         Indonesia    284,438,782       3.5%
# 3          Pakistan    241,499,431       2.9%
# 4           Nigeria    223,800,000       2.7%
# 5            Brazil    213,421,037       2.6%
# 6        Bangladesh    169,828,911       2.1%
# 7            Mexico    130,760,049       1.6%
# 8             Japan    122,950,000        15%
# 9       Philippines    114,123,600       1.4%
# 10  Republic of the    112,832,000       1.4%
# 11         Ethiopia    111,652,998       1.4%
# 12            Egypt    107,868,296       1.3%
# 13          Vietnam    102,300,000       1.2%
# 14             Iran     86,563,000       1.1%
# 15           France     69,081,996       0.8%
# 16         Tanzania     68,153,004       0.8%
# 17         Thailand     65,826,149       0.8%
# 18     South Africa     63,100,945       0.8%
# ...
